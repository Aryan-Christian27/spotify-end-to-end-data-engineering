# %%
pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = '2d9b2643d77f492dab35258631390966' , client_secret = 'a30c261c268b40249d2d46379596efba')

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = 'https://open.spotify.com/playlist/1ZWGccQoTFB3fDYt6kJJ9B'

# %%
playlist_URI =playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '15yvc643iYfQtb6zh9NEJo'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'a thousand years'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2011-10-18'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/15yvc643iYfQtb6zh9NEJo'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id' : album_id , 'name' : album_name , 'release_date': album_release_date,
                     'total_tracke' : album_total_tracks , 'url' : album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '15yvc643iYfQtb6zh9NEJo',
#   'name': 'a thousand years',
#   'release_date': '2011-10-18',
#   'total_tracke': 1,
#   'url': 'https://open.spotify.com/album/15yvc643iYfQtb6zh9NEJo'},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracke': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': '78bpIziExqiI9qztvNFlQu',
#   'name': 'AM',
#   'release_date': '2013-09-09',
#   'total_tracke': 12,
#   'url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': '7ARtQpvnPN2ucbmVHngLOs',
#   'name': 'Until I Found You (Em Beihold Version)',
#   'release_date': '2022-04-22',
#   'total_tracke': 1,
#   'url': 'https://open.spotify.com/album/7ARtQpvnPN2ucbmVHngLOs'},
#  {'album_id': '4gCNyS7pidfK3rKWhB3JOY',
#   'name': 'FOUR (Deluxe)',
#   'release_date': '2014-11-17',
#   'total_tracke': 16,
# ...

# %%
data['items'][6]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#   'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#   'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'name': 'Billie Eilish',
#   'type': 'artist',
#   'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#   'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#   'id': '6LuN9FCkKOj5PcnpouEgny',
#   'name': 'Khalid',
#   'type': 'artist',
#   'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value ['artists']:
                artist_dict = {'artist_id' : artist['id'], 'artist_name' : artist['name'],
                              'external_url' : artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '7H55rcKCfwqkyDFH9wpKM6',
#   'artist_name': 'Christina Perri',
#   'external_url': 'https://api.spotify.com/v1/artists/7H55rcKCfwqkyDFH9wpKM6'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'artist_name': 'Arctic Monkeys',
#   'external_url': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_id': '5XKFrudbV4IiuE5WuTPRmT',
#   'artist_name': 'Stephen Sanchez',
#   'external_url': 'https://api.spotify.com/v1/artists/5XKFrudbV4IiuE5WuTPRmT'},
#  {'artist_id': '7o2ZQYM7nTsaVdkXY38UAA',
#   'artist_name': 'Em Beihold',
#   'external_url': 'https://api.spotify.com/v1/artists/7o2ZQYM7nTsaVdkXY38UAA'},
#  {'artist_id': '4AK6F7OLvEQ5QYCBNiQWHq',
#   'artist_name': 'One Direction',
#   'external_url': 'https://api.spotify.com/v1/artists/4AK6F7OLvEQ5QYCBNiQWHq'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id' : song_id, 'song_name' : song_name, 'duration_ms' : song_duration, 'url' : song_url,
                   'popularity' : song_popularity, 'song_added' : song_added, 'album_id' : album_id, 'artist_id' : artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '6lanRgr6wXibZr8KgzXxBl',
#   'song_name': 'a thousand years',
#   'duration_ms': 285120,
#   'url': 'https://open.spotify.com/track/6lanRgr6wXibZr8KgzXxBl',
#   'popularity': 83,
#   'song_added': '2024-06-15T14:17:46Z',
#   'album_id': '15yvc643iYfQtb6zh9NEJo',
#   'artist_id': '7H55rcKCfwqkyDFH9wpKM6'},
#  {'song_id': '0tgVpDi06FyKpA1z0VMD4v',
#   'song_name': 'Perfect',
#   'duration_ms': 263400,
#   'url': 'https://open.spotify.com/track/0tgVpDi06FyKpA1z0VMD4v',
#   'popularity': 87,
#   'song_added': '2024-06-15T14:17:58Z',
#   'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '5XeFesFbtLpXzIVDNQP22n',
#   'song_name': 'I Wanna Be Yours',
#   'duration_ms': 183956,
#   'url': 'https://open.spotify.com/track/5XeFesFbtLpXzIVDNQP22n',
#   'popularity': 90,
#   'song_added': '2024-06-15T14:18:07Z',
#   'album_id': '78bpIziExqiI9qztvNFlQu',
#   'artist_id': '7Ln80lUS6He07XvHI8qqHH'},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                                               name  \
# 0   15yvc643iYfQtb6zh9NEJo                                   a thousand years
# 1   3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2   78bpIziExqiI9qztvNFlQu                                                 AM
# 3   7ARtQpvnPN2ucbmVHngLOs             Until I Found You (Em Beihold Version)
# 4   4gCNyS7pidfK3rKWhB3JOY                                      FOUR (Deluxe)
# 5   1NAmidJlEaVgA3MpcPFYGq                                              Lover
# 6   2sBB17RXTamvj7Ncps15AK                               lovely (with Khalid)
# 7   4xkM0BwLM9H2IUcbYzpcBI                                        I Love You.
# 8   2Cn1d2KgbkAqbZCJ1RzdkA             The Land Is Inhospitable and So Are We
# 9   6EWWmTEOXI58PL13vNk67S                                          Fairytale
# 10  2ODvWsOgouMbaA5xf0RkJe                                            Starboy
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      57 non-null     object
#  1   name          57 non-null     object
#  2   release_date  57 non-null     object
#  3   total_tracke  57 non-null     int64
#  4   url           57 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.4+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df
# Out:
#                   album_id                                               name  \
# 0   15yvc643iYfQtb6zh9NEJo                                   a thousand years
# 1   3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2   78bpIziExqiI9qztvNFlQu                                                 AM
# 3   7ARtQpvnPN2ucbmVHngLOs             Until I Found You (Em Beihold Version)
# 4   4gCNyS7pidfK3rKWhB3JOY                                      FOUR (Deluxe)
# 5   1NAmidJlEaVgA3MpcPFYGq                                              Lover
# 6   2sBB17RXTamvj7Ncps15AK                               lovely (with Khalid)
# 7   4xkM0BwLM9H2IUcbYzpcBI                                        I Love You.
# 8   2Cn1d2KgbkAqbZCJ1RzdkA             The Land Is Inhospitable and So Are We
# 9   6EWWmTEOXI58PL13vNk67S                                          Fairytale
# 10  2ODvWsOgouMbaA5xf0RkJe                                            Starboy
# ...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     76 non-null     object
#  1   artist_name   76 non-null     object
#  2   external_url  76 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df
# Out:
#                  artist_id           artist_name  \
# 0   7H55rcKCfwqkyDFH9wpKM6       Christina Perri
# 1   6eUKZXaKkcviH0Ku9w2n3V            Ed Sheeran
# 2   7Ln80lUS6He07XvHI8qqHH        Arctic Monkeys
# 3   5XKFrudbV4IiuE5WuTPRmT       Stephen Sanchez
# 4   7o2ZQYM7nTsaVdkXY38UAA            Em Beihold
# 5   4AK6F7OLvEQ5QYCBNiQWHq         One Direction
# 6   06HL4z0CvFAxyc27GXpf02          Taylor Swift
# 7   6qqNVTkY8uBg9cP3Jd7DAH         Billie Eilish
# 8   6LuN9FCkKOj5PcnpouEgny                Khalid
# 9   77SW9BnxLY8rJ0RciFqkHh     The Neighbourhood
# 10  2uYWxilOVlUdk4oV9DvwqK                Mitski
# 11  3LLNDXrxL4uxXtnUJS5XWM       Alexander Rybak
# 12  1Xyo4u8uXC1ZmMpatF05PJ            The Weeknd
# 13  4tZwfgrHOc3mvqYlEYSvVi             Daft Punk
# 14  00FQb4jTyendYWaN8pK0wa          Lana Del Rey
# 16  1HY2Jd0NmPuamShAr6KMms             Lady Gaga
# 17  0gadJ2b9A4SKsB1RFkBb66             Passenger
# 19  6Ff53KvcvAj5U7Z1vojB5o                *NSYNC
# ...

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   6lanRgr6wXibZr8KgzXxBl                                   a thousand years
# 1   0tgVpDi06FyKpA1z0VMD4v                                            Perfect
# 2   5XeFesFbtLpXzIVDNQP22n                                   I Wanna Be Yours
# 3   1Y3LN4zO1Edc2EluIoSPJN  Until I Found You (with Em Beihold) - Em Beiho...
# 4   5O2P9iiztwhomNh8xkR9lJ                                      Night Changes
# 5   1dGr1c8CrMLDpV6mPbImSI                                              Lover
# 6   0u2P5u6lvoDfwTYjAADbn4                               lovely (with Khalid)
# 7   2QjOHCTQ1Jl3zawyYOpxh6                                    Sweater Weather
# 8   3vkCueOmm7xQDoJ17W1Pm3                              My Love Mine All Mine
# 9   3MnAsEBBsEj86d03RgO4EM                                          Fairytale
# 10  7MXVkk9YMctZqd1Srtv4MB                                            Starboy
# ...

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  6lanRgr6wXibZr8KgzXxBl                                   a thousand years
# 1  0tgVpDi06FyKpA1z0VMD4v                                            Perfect
# 2  5XeFesFbtLpXzIVDNQP22n                                   I Wanna Be Yours
# 3  1Y3LN4zO1Edc2EluIoSPJN  Until I Found You (with Em Beihold) - Em Beiho...
# 4  5O2P9iiztwhomNh8xkR9lJ                                      Night Changes
#
#    duration_ms                                                url  popularity  \
# 0       285120  https://open.spotify.com/track/6lanRgr6wXibZr8...          83
# 1       263400  https://open.spotify.com/track/0tgVpDi06FyKpA1...          87
# 2       183956  https://open.spotify.com/track/5XeFesFbtLpXzIV...          90
# 3       176440  https://open.spotify.com/track/1Y3LN4zO1Edc2El...          79
# 4       226600  https://open.spotify.com/track/5O2P9iiztwhomNh...          87
#
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      57 non-null     object
#  1   song_name    57 non-null     object
#  2   duration_ms  57 non-null     int64
#  3   url          57 non-null     object
#  4   popularity   57 non-null     int64
#  5   song_added   57 non-null     datetime64[ns, UTC]
#  6   album_id     57 non-null     object
#  7   artist_id    57 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.7+ KB

# %%
album_df.head()
# Out:
#                  album_id                                    name  \
# 0  15yvc643iYfQtb6zh9NEJo                        a thousand years
# 1  3T4tUhGYeRNVUGevb0wThu                              ÷ (Deluxe)
# 2  78bpIziExqiI9qztvNFlQu                                      AM
# 3  7ARtQpvnPN2ucbmVHngLOs  Until I Found You (Em Beihold Version)
# 4  4gCNyS7pidfK3rKWhB3JOY                           FOUR (Deluxe)
#
#   release_date  total_tracke  \
# 0   2011-10-18             1
# 1   2017-03-03            16
# 2   2013-09-09            12
# 3   2022-04-22             1
# 4   2014-11-17            16
#
#                                                  url
# 0  https://open.spotify.com/album/15yvc643iYfQtb6...
# 1  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2  https://open.spotify.com/album/78bpIziExqiI9qz...
# 3  https://open.spotify.com/album/7ARtQpvnPN2ucbm...
# 4  https://open.spotify.com/album/4gCNyS7pidfK3rK...

# %%
artist_df.head()
# Out:
#                 artist_id      artist_name  \
# 0  7H55rcKCfwqkyDFH9wpKM6  Christina Perri
# 1  6eUKZXaKkcviH0Ku9w2n3V       Ed Sheeran
# 2  7Ln80lUS6He07XvHI8qqHH   Arctic Monkeys
# 3  5XKFrudbV4IiuE5WuTPRmT  Stephen Sanchez
# 4  7o2ZQYM7nTsaVdkXY38UAA       Em Beihold
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/7H55rcKCfwq...
# 1  https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 2  https://api.spotify.com/v1/artists/7Ln80lUS6He...
# 3  https://api.spotify.com/v1/artists/5XKFrudbV4I...
# 4  https://api.spotify.com/v1/artists/7o2ZQYM7nTs...

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  6lanRgr6wXibZr8KgzXxBl                                   a thousand years
# 1  0tgVpDi06FyKpA1z0VMD4v                                            Perfect
# 2  5XeFesFbtLpXzIVDNQP22n                                   I Wanna Be Yours
# 3  1Y3LN4zO1Edc2EluIoSPJN  Until I Found You (with Em Beihold) - Em Beiho...
# 4  5O2P9iiztwhomNh8xkR9lJ                                      Night Changes
#
#    duration_ms                                                url  popularity  \
# 0       285120  https://open.spotify.com/track/6lanRgr6wXibZr8...          83
# 1       263400  https://open.spotify.com/track/0tgVpDi06FyKpA1...          87
# 2       183956  https://open.spotify.com/track/5XeFesFbtLpXzIV...          90
# 3       176440  https://open.spotify.com/track/1Y3LN4zO1Edc2El...          79
# 4       226600  https://open.spotify.com/track/5O2P9iiztwhomNh...          87
#
# ...

# %%
playlists = sp.user_playlists('spotify')
